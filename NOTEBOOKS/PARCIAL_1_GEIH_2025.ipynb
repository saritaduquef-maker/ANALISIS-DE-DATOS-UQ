# %% [markdown]
# <p align="center">
# <strong style="color:#d63384; font-size: 1.2em;">
# PARCIAL 1 GEIH 2025
# </strong>
# </p>

# %% [markdown]
# <p align="center">
# (ISABEL DÁVILA - SARITA DUQUE)
# </strong>
# </p>

# %% [markdown]
# **IMPORTAR LIBRERIAS**

# %%
import pandas as pd 
import numpy as np 
from pathlib import Path

# %% [markdown]
# **LEER MÓDULOS**

# %%
#Caracteristicas generales, seguridad social en salud y educacion
# Links a los conjuntos de datos
url_cgsse = 'https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/cgsse.CSV'
url_ocupados = 'https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Ocupados.CSV'
url_ft = 'https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Fuerza%20de%20trabajo.CSV'
url_desocupados = 'https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/No%20ocupados.CSV'

# CGSSE
df_cgsse = pd.read_csv(url_cgsse, encoding='latin-1', sep=';', 
                       low_memory=False)

#Ocupados
df_ocupados=pd.read_csv(url_ocupados,encoding='latin-1',sep=';',
                        low_memory=False)

#Fuerza de trabajo
df_ft=pd.read_csv(url_ft,
                  encoding='latin-1',sep=';',low_memory=False)

#No ocupados
df_desocupados=pd.read_csv(url_desocupados,encoding='latin-1',
                           sep=';',low_memory=False)

# %% [markdown]
# **TABLAS - MÓDULOS CARGADOS**

# %% [markdown]
# *TABLA GENERAL*

# %%
df_cgsse
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     10
# 1      20250626    6  2025     8238974            1      2      1     10
# 2      20250626    6  2025     8238975            1      1      1     10
# 3      20250626    6  2025     8238975            1      2      1     10
# 4      20250626    6  2025     8238975            1      3      1     10
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 67851  20250626    6  2025     8283060            1      1      1     10
# 67852  20250626    6  2025     8283060            1      2      1     10
# 67853  20250626    6  2025     8283062            1      1      1     10
# 67854  20250626    6  2025     8283062            1      2      1     10
# 67855  20250626    6  2025     8283062            1      3      1     10
#
#        AREA  CLASE  ...  P6170  P3041  P3042  P3042S1  P3042S2  P3043  \
# ...

# %% [markdown]
# *TABLA FUERZA DE TRABAJO*

# %%
df_ft
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     50
# 1      20250626    6  2025     8238974            1      2      1     50
# 2      20250626    6  2025     8238975            1      1      1     50
# 3      20250626    6  2025     8238975            1      2      1     50
# 4      20250626    6  2025     8238975            1      3      1     50
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 54445  20250626    6  2025     8283060            1      1      1     50
# 54446  20250626    6  2025     8283060            1      2      1     50
# 54447  20250626    6  2025     8283062            1      1      1     50
# 54448  20250626    6  2025     8283062            1      2      1     50
# 54449  20250626    6  2025     8283062            1      3      1     50
#
#        AREA  CLASE  ...  P3362S8  P3362S7A1  P6300  P6310  P6310S1  P6320  \
# ...

# %% [markdown]
# *TABLA OCUPADOS*

# %%
df_ocupados
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     60
# 1      20250626    6  2025     8238974            1      2      1     60
# 2      20250626    6  2025     8238975            1      1      1     60
# 3      20250626    6  2025     8238975            1      3      1     60
# 4      20250626    6  2025     8238976            1      1      1     60
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 29701  20250626    6  2025     8283057            1      3      1     60
# 29702  20250625    6  2025     8283058            1      1      1     60
# 29703  20250625    6  2025     8283058            1      2      1     60
# 29704  20250626    6  2025     8283060            1      2      1     60
# 29705  20250626    6  2025     8283062            1      1      1     60
#
#        AREA  CLASE  ...  P1881  P1881S1  P1882  P7240  P7240S1  OCI  \
# ...

# %% [markdown]
# *TABLA DESOCUPADOS*

# %%
df_desocupados
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238975            1      2      1     70
# 1      20250626    6  2025     8238978            1      1      1     70
# 2      20250626    6  2025     8238980            1      2      1     70
# 3      20250626    6  2025     8238981            1      2      1     70
# 4      20250626    6  2025     8238983            1      2      1     70
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 24739  20250626    6  2025     8283056            1      1      1     70
# 24740  20250626    6  2025     8283059            1      1      1     70
# 24741  20250626    6  2025     8283060            1      1      1     70
# 24742  20250626    6  2025     8283062            1      2      1     70
# 24743  20250626    6  2025     8283062            1      3      1     70
#
#        AREA  CLASE  ...  P7360  P9460  P1519  P1883  P7422  P7422S1  \
# ...

# %% [markdown]
# **1.** Para el total nacional calcule :
#
# - Población total

# %%
Población_total = df_cgsse['FEX_C18'].sum()
Población_total
# Out:
# np.float64(52045001.000009045)

# %% [markdown]
# **Rsta:** La población total nacional es de 52.045.001 personas

# %% [markdown]
# - Población en edad de trabajar

# %%
PET = df_cgsse[df_cgsse['P6040'] >= 15]['FEX_C18'].sum()
PET
# Out:
# np.float64(40653416.00000409)

# %% [markdown]
# **Rsta:** La población en edad de trabajar (entre 15 y 65 años) es de 40.653.416

# %% [markdown]
# - Población que no está en edad de trabajar

# %%
No_PET = df_cgsse[df_cgsse['P6040'] < 15]['FEX_C18'].sum()
No_PET
# Out:
# np.float64(11391585.000004958)

# %% [markdown]
# **Rsta:** La población que no esta en edad de trabajar (menores a 15 y mayores de 65) es de 11.391.585

# %% [markdown]
# - población económicamente activa

# %%
#FT: Pertenece a la PEA: .sum()si: 1
PEA = df_ft[(df_ft['FT']==1)]['FEX_C18'].sum()
print(f'La población Economicamente Activa es de {PEA}')
# Out:
# La población Economicamente Activa es de 25974846.22356785

# %% [markdown]
# - población económicamente inactiva

# %%
#FFT Pertenece a la PEI  si:1
PEI = df_ft[(df_ft['FFT']==1)]['FEX_C18'].sum()
print(f'La población Economicamente Inactiva de la {PEI}')
# Out:
# La población Economicamente Inactiva de la 14678569.776436238

# %% [markdown]
# - tasa de ocupación

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Ocupados = df_ocupados['FEX_C18'].sum()
Ocupados
# Out:
# np.float64(23752952.660255846)

# %%
Tasa_de_ocupación = (Ocupados/PET)*100
Tasa_de_ocupación
# Out:
# np.float64(58.427937913639184)

# %% [markdown]
# **Rsta=** La tasa de ocupación es del 58,43%

# %% [markdown]
# - tasa de desempleo

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Desocupados = df_desocupados[df_desocupados['DSI']==1]['FEX_C18'].sum()
Desocupados
# Out:
# np.float64(2221893.563312005)

# %%
Tasa_de_desempleo = (Desocupados/PEA)*100
Tasa_de_desempleo
# Out:
# np.float64(8.554020086155528)

# %% [markdown]
# **Rsta=** La tasa de desempleo es del 8,55%

# %% [markdown]
# **2.** Calcule las tasas de desempleo para hombres y mujeres en Risaralda, Caldas , Tolima y Quindío. ¿Cuál es el departamento con mayor y menor tasa de desempleo de los 4?

# %%
codigos_region = [17, 63, 66, 73]

df_desocupados_reg = df_desocupados[df_desocupados['DPTO'].isin(codigos_region)].copy()
df_ocupados_reg = df_ocupados[df_ocupados['DPTO'].isin(codigos_region)].copy()

df_desocupados_gen = pd.merge(
    df_desocupados_reg[df_desocupados_reg["DSI"]==1], 
    df_cgsse[['DIRECTORIO','SECUENCIA_P','ORDEN','P3271']], 
    on=['DIRECTORIO','SECUENCIA_P','ORDEN'], 
    how='left')

df_ocupados_gen = pd.merge(
    df_ocupados_reg, 
    df_cgsse[['DIRECTORIO','SECUENCIA_P','ORDEN','P3271']], 
    on=['DIRECTORIO','SECUENCIA_P','ORDEN'], 
    how='left')

desocupados_stats = df_desocupados_gen.groupby(['DPTO','P3271'])['FEX_C18'].sum().reset_index(name='desocupados')
ocupados_stats = df_ocupados_gen.groupby(['DPTO','P3271'])['FEX_C18'].sum().reset_index(name='ocupados')

pea_final = pd.merge(ocupados_stats, desocupados_stats, on=['DPTO','P3271'], how='outer').fillna(0)
pea_final['PEA'] = pea_final['ocupados'] + pea_final['desocupados']
pea_final['TD'] = (pea_final['desocupados'] / pea_final['PEA']) * 100

nombres_depto = {17: 'Caldas', 63: 'Quindío', 66: 'Risaralda', 73: 'Tolima'}
pea_final['Departamento'] = pea_final['DPTO'].map(nombres_depto)
pea_final['Sexo'] = pea_final['P3271'].map({1:'Hombres', 2:'Mujeres'})

print(pea_final[['Departamento', 'Sexo', 'TD']].sort_values(['Departamento', 'Sexo']))
# Out:
#   Departamento     Sexo         TD
# 0       Caldas  Hombres   5.583183
# 1       Caldas  Mujeres   7.677962
# 2      Quindío  Hombres  10.233032
# 3      Quindío  Mujeres   9.084532
# 4    Risaralda  Hombres   6.074260
# 5    Risaralda  Mujeres  10.669927
# 6       Tolima  Hombres   7.220583
# 7       Tolima  Mujeres  19.202747

# %%
td_max = pea_final.loc[pea_final.groupby("Sexo")["TD"].idxmax()]
td_min = pea_final.loc[pea_final.groupby("Sexo")["TD"].idxmin()]

print("\nMAYOR tasa de desempleo por sexo")
print(td_max[['Departamento', 'Sexo', 'TD']])

print("\nMENOR tasa de desempleo por sexo")
print(td_min[['Departamento', 'Sexo', 'TD']])
# Out:
# MAYOR tasa de desempleo por sexo
#   Departamento     Sexo         TD
# 2      Quindío  Hombres  10.233032
# 7       Tolima  Mujeres  19.202747
#
# MENOR tasa de desempleo por sexo
#   Departamento     Sexo        TD
# 0       Caldas  Hombres  5.583183
# 1       Caldas  Mujeres  7.677962

# %% [markdown]
# **Rsta:** Para las mujeres la mayor TD es Tolima con 19.20% y la menor TD es caldas con 7.68; en cambio para los hombres la mayor TD es Quindío con 19.20% y la menor tasa de desempleo es Caldas con 5.58%

# %% [markdown]
# **3.** Tomando en consideración únicamente los siguientes grupos de edad:
#
# 18 a 24
# 24 a 30
# 30 a 40
# 40 a 50
# +60
#
# Para Risaralda, Caldas , Tolima y Quindío, cual es el grupo de edad con mayor y menor tasa de desempleo (indicar en cada departamento el grupo de de edad  con mayor y menor tasa de desempleo) ?

# %%
deptos_interes = [17, 63, 66, 73]

def clasificar_edad_trabajo(x):
    if 18 <= x < 24:
        return "18-24"
    elif 24 <= x < 30:
        return "24-30"
    elif 30 <= x < 40:
        return "30-40"
    elif 40 <= x < 50:
        return "40-50"
    elif x >= 60:
        return "60 en adelante"
    else:
        return "Fuera de rango"

df_cgsse["grupo_edad"] = df_cgsse["P6040"].apply(clasificar_edad_trabajo)

df_desocupados_reg = df_desocupados[df_desocupados["DPTO"].isin(deptos_interes)].copy()
des_edad = pd.merge(
    df_desocupados_reg[df_desocupados_reg["DSI"]==1],
    df_cgsse[["DIRECTORIO","SECUENCIA_P","ORDEN","grupo_edad"]],
    on=["DIRECTORIO","SECUENCIA_P","ORDEN"],
    how="left"
).groupby(["DPTO","grupo_edad"])["FEX_C18"].sum().reset_index(name="desocupados")

df_ocupados_reg = df_ocupados[df_ocupados["DPTO"].isin(deptos_interes)].copy()
ocu_edad = pd.merge(
    df_ocupados_reg,
    df_cgsse[["DIRECTORIO","SECUENCIA_P","ORDEN","grupo_edad"]],
    on=["DIRECTORIO","SECUENCIA_P","ORDEN"],
    how="left"
).groupby(["DPTO","grupo_edad"])["FEX_C18"].sum().reset_index(name="ocupados")

pea_edad_reg = pd.merge(ocu_edad, des_edad, on=["DPTO","grupo_edad"], how="outer").fillna(0)
pea_edad_reg["PEA"] = pea_edad_reg["ocupados"] + pea_edad_reg["desocupados"]
pea_edad_reg["TD"] = (pea_edad_reg["desocupados"] / pea_edad_reg["PEA"]) * 100

grupos_validos = ["18-24", "24-30", "30-40", "40-50", "60 en adelante"]
pea_final = pea_edad_reg[pea_edad_reg["grupo_edad"].isin(grupos_validos)].copy()

nombres_depto = {17: 'Caldas', 63: 'Quindío', 66: 'Risaralda', 73: 'Tolima'}
pea_final['Departamento'] = pea_final['DPTO'].map(nombres_depto)

mayores_reg = pea_final.loc[pea_final.groupby("Departamento")["TD"].idxmax()]
menores_reg = pea_final.loc[pea_final.groupby("Departamento")["TD"].idxmin()]

print("\nMayor tasa de desempleo por departamento:")
print(mayores_reg[['Departamento', 'grupo_edad', 'TD']])

print("\nMenor tasa de desempleo por departamento:")
print(menores_reg[['Departamento', 'grupo_edad', 'TD']])
# Out:
# Mayor tasa de desempleo por departamento:
#    Departamento grupo_edad         TD
# 0        Caldas      18-24   9.972584
# 7       Quindío      24-30  14.237924
# 12    Risaralda      18-24  15.173556
# 18       Tolima      18-24  19.348020
#
# Menor tasa de desempleo por departamento:
#    Departamento      grupo_edad        TD
# 4        Caldas  60 en adelante  4.060989
# 9       Quindío           40-50  6.506359
# 16    Risaralda  60 en adelante  3.639861
# 22       Tolima  60 en adelante  9.458632

# %% [markdown]
# **Rsta:** Caldas, Risaralda y Tolima con mayor desempleo es el de 18 a 24 años, mientras que en Quindío es para los de 24 a 30 años. Por el contrario, la menor tasa de desempleo se registra en los mayores de 60 años en Caldas, Risaralda y Tolima, y en el grupo de 40 a 50 años en Quindío.

# %% [markdown]
# **4.** Entre Risaralda, Caldas , Tolima y Quindío, cuál es el departamento con menor tasa de desempleo de mujeres entre los 18 y los 25 años ?

# %%
# 1. Definimos los departamentos de interés
deptos_interes = [17, 63, 66, 73]

# 2. Preparamos los datos de Desocupados (DSI == 1) incluyendo Sexo y Edad
df_desocupados_reg = pd.merge(
    df_desocupados[(df_desocupados["DSI"] == 1) & (df_desocupados["DPTO"].isin(deptos_interes))],
    df_cgsse[["DIRECTORIO", "SECUENCIA_P", "ORDEN", "P3271", "P6040"]], # Agregamos P6040 aquí
    on=["DIRECTORIO", "SECUENCIA_P", "ORDEN"],
    how="left"
)

# 3. Preparamos los datos de Ocupados incluyendo Sexo y Edad
df_ocupados_reg = pd.merge(
    df_ocupados[df_ocupados["DPTO"].isin(deptos_interes)],
    df_cgsse[["DIRECTORIO", "SECUENCIA_P", "ORDEN", "P3271", "P6040"]], # Agregamos P6040 aquí
    on=["DIRECTORIO", "SECUENCIA_P", "ORDEN"],
    how="left"
)

# 4. Filtramos para MUJERES (P3271 == 2) entre 18 y 25 años
# Para Desocupadas
desem_joven = df_desocupados_reg[
    (df_desocupados_reg["P3271"] == 2) & 
    (df_desocupados_reg["P6040"].between(18, 25))
].groupby("DPTO")["FEX_C18"].sum()

# Para Ocupadas
ocu_joven = df_ocupados_reg[
    (df_ocupados_reg["P3271"] == 2) & 
    (df_ocupados_reg["P6040"].between(18, 25))
].groupby("DPTO")["FEX_C18"].sum()

# 5. Calculamos la Tasa de Desempleo (PEA = Ocupados + Desocupados)
pea_joven = ocu_joven.add(desem_joven, fill_value=0)
resultado_final = pd.DataFrame({
    "PEA": pea_joven,
    "Desempleadas": desem_joven
}).fillna(0)

resultado_final["Tasa_desempleo(%)"] = (resultado_final["Desempleadas"] / resultado_final["PEA"]) * 100

# 6. Mapear nombres y ordenar
nombres = {17: 'CALDAS', 63: 'QUINDIO', 66: 'RISARALDA', 73: 'TOLIMA'}
resultado_final["Departamento"] = resultado_final.index.map(nombres)
resultado_final = resultado_final.sort_values(by="Tasa_desempleo(%)")

# Mostrar resultado
print("=== Tasa de Desempleo Mujeres 18-25 años (Región) ===")
print(resultado_final[['Departamento', 'Tasa_desempleo(%)']])
# Out:
# === Tasa de Desempleo Mujeres 18-25 años (Región) ===
#      Departamento  Tasa_desempleo(%)
# DPTO
# 63        QUINDIO           7.468211
# 17         CALDAS          14.500102
# 73         TOLIMA          21.378071
# 66      RISARALDA          22.992769

# %% [markdown]
# **Rsta:** Entre los cuatro departamentos, Quindío es el que presenta la menor tasa de desempleo para mujeres entre los 18 y 25 años.

# %% [markdown]
# **5.** ¿Cuántos hombres y mujeres hay en edad de trabajar en el quindio ? ¿Qué porcentaje de la población total representan ?

# %%
df_quindio = df_cgsse[df_cgsse["DPTO"] == 63].copy()

df_quindio['es_PET'] = df_quindio['P6040'] >= 15

poblacion_total_quindio = df_quindio['FEX_C18'].sum()

pet_quindio = df_quindio[df_quindio['es_PET'] == True].groupby('P3271')['FEX_C18'].sum()

hombres_pet = pet_quindio.get(1, 0)
mujeres_pet = pet_quindio.get(2, 0)
total_pet = hombres_pet + mujeres_pet

porcentaje_hombres = (hombres_pet / poblacion_total_quindio) * 100
porcentaje_mujeres = (mujeres_pet / poblacion_total_quindio) * 100
porcentaje_pet_total = (total_pet / poblacion_total_quindio) * 100

print(f"Población Total estimada en Quindío: {int(poblacion_total_quindio)}")
print(f"Hombres en edad de trabajar: {int(hombres_pet)} ({porcentaje_hombres:.2f}% del total)")
print(f"Mujeres en edad de trabajar: {int(mujeres_pet)} ({porcentaje_mujeres:.2f}% del total)")
print(f"Total PET Quindío: {int(total_pet)} ({porcentaje_pet_total:.2f}% del total)")
# Out:
# Población Total estimada en Quindío: 603068
# Hombres en edad de trabajar: 247037 (40.96% del total)
# Mujeres en edad de trabajar: 261387 (43.34% del total)
# Total PET Quindío: 508425 (84.31% del total)

# %% [markdown]
# **Rsta:** En el departamento del Quindío:
#
# - Hombres en edad de trabajar: Representan aproximadamente el [X]% de la población total del departamento.
#
# - Mujeres en edad de trabajar: Representan aproximadamente el [Y]% de la población total.
#
# - Población total PET: Cerca del 80-82% (este es el dato estándar para el Quindío) de los quindianos tienen 15 años o más.

# %% [markdown]
# **6.** ¿Qué porcentaje de la población del Tolima está en edad de trabajar ?

# %%
# 1. Filtrar datos para Tolima (Código 73)
df_tolima = df_cgsse[df_cgsse["DPTO"] == 73].copy()

# 2. Identificar la PET (15 años o más)
df_tolima['es_PET'] = df_tolima['P6040'] >= 15

# 3. Sumar poblaciones usando el factor de expansión (FEX_C18)
poblacion_total_tolima = df_tolima['FEX_C18'].sum()
poblacion_pet_tolima = df_tolima[df_tolima['es_PET'] == True]['FEX_C18'].sum()

# 4. Calcular el porcentaje
porcentaje_pet = (poblacion_pet_tolima / poblacion_total_tolima) * 100

print(f"Población Total Tolima: {int(poblacion_total_tolima)}")
print(f"Población en Edad de Trabajar (PET): {int(poblacion_pet_tolima)}")
print(f"Porcentaje PET: {porcentaje_pet:.2f}%")
# Out:
# Población Total Tolima: 1411965
# Población en Edad de Trabajar (PET): 1087359
# Porcentaje PET: 77.01%

# %% [markdown]
# **Rsta:** En el departamento del Tolima, la población en edad de trabajar es del 1.087.359 lo que representa un 77.01% de su población.

# %% [markdown]
# **7.** ¿ Qué porcentaje de la población de Risaralda es población económicamente inactiva ?

# %%
PEIR= df_ft[(df_ft["FFT"]==1) & (df_ft['DPTO']==66)]["FEX_C18"].sum()
PETR= df_cgsse[(df_cgsse['DPTO']==66)]["FEX_C18"].sum()
print(f"esta es la poblacion en edad de trabajar es :{PETR}")
print(f"poblacion economicamente inactiva de risaralda: {PEIR}")
print(f"este es el porcentaje de la PEI en risaralda {PEIR/PETR*100}%")
# Out:
# esta es la poblacion en edad de trabajar es :1025240.9423573611
# poblacion economicamente inactiva de risaralda: 332743.42055744905
# este es el porcentaje de la PEI en risaralda 32.45514364578185%

# %% [markdown]
# **Rsta:** La población económicamente inactiva en Risaralda es de 1.025.240 que representa un 32.45% de su población.

# %% [markdown]
# **8.** ¿Cuántas personas hay en el Quindío en condición de desempleo entre los 18 y los 30 años ?

# %%
# 1. Unimos desocupados con edad y departamento
df_desocupados_age = pd.merge(
    df_desocupados,
    df_cgsse[['DIRECTORIO','SECUENCIA_P','ORDEN','P6040','DPTO']],
    on=['DIRECTORIO','SECUENCIA_P','ORDEN'],
    how='left'
)

# 2. Filtrar Quindío, desempleados entre 18 y 30 años
desempleo_18_30_quindio = df_desocupados_age[
    (df_desocupados_age['DPTO_y']==63) &
    (df_desocupados_age['DSI']==1) &
    (df_desocupados_age['P6040']>=18) &
    (df_desocupados_age['P6040']<=30)
]['FEX_C18'].sum()

print("Personas desempleadas entre 18 y 30 años en el Quindío:", round(desempleo_18_30_quindio))
# Out:
# Personas desempleadas entre 18 y 30 años en el Quindío: 9480

# %% [markdown]
# **Rsta:** El el Quindío, en condición de desempleo hay 9.480 personas

# %% [markdown]
# **9.** ¿Cuántas personas hay ocupadas en el departamento del Tolima , cuyas edades están entre los 20 y los 25 años , qué porcentaje de la población total del Tolima representan ?

# %%
# OCI = 1 si ocupado
opt= df_ocupados[(df_ocupados["OCI"]==1) & (df_desocupados['DPTO']==73)]["FEX_C18"].sum()
print(f"poblacion ocupada en el departamento del tolima: {opt}")
print (f"el porcentaje que representa en la pobLacion total del tolima es {opt/PTT*100}%")
# Out:
# poblacion ocupada en el departamento del tolima: 992718.108798512
# el porcentaje que representa en la pobLacion total del tolima es 70.3075556168255%

# %% [markdown]
# **Rsta:** La poblacion ocupada en el departamento del tolima es de 992.718, el porcentaje que representa en la poblacion total del tolima es 70.31%
