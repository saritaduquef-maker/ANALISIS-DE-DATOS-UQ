# %% [markdown]
# INDICADORES DEL MERCADO LABORAL MEDIANTE LA METODOLOGIA DANE: EXPLORACIÓN Y ANALISIS DESCRIPTIVO DE LOS RESULTADOS DE LA GEIH 2025 (DICIEMBRE)

# %%
import pandas as pd 
import numpy as np 
from pathlib import Path
